# %% [markdown]
# ## Prerequisites

# %%
# %load_ext autoreload
# %autoreload 2

from data import get_data
from sklearn.linear_model import LinearRegression
import pandas as pd

# %% [markdown]
# ## Load data

# %%
df = get_data()

# %%
df.loc[1, 'BVP']
# Out:
#           BVP                       time  time_seconds
# 0       -3.40 2021-12-17 16:24:08.281250      0.000000
# 1      -12.83 2021-12-17 16:24:08.296875      0.015625
# 2      -15.64 2021-12-17 16:24:08.312500      0.031250
# 3      -14.60 2021-12-17 16:24:08.328125      0.046875
# 4      -13.47 2021-12-17 16:24:08.343750      0.062500
# ...       ...                        ...           ...
# 25076  366.27 2021-12-17 16:30:40.093750    391.812500
# 25077  392.14 2021-12-17 16:30:40.109375    391.828125
# 25078  405.07 2021-12-17 16:30:40.125000    391.843750
# 25079  400.74 2021-12-17 16:30:40.140625    391.859375
# 25080  376.32 2021-12-17 16:30:40.156250    391.875000
#
# [25081 rows x 3 columns]

# %%
df.to_pickle("data_df.pkl")

# %% [markdown]
# ## Fit linear model to biosignals

# %%
measurements = ["BVP", "EDA", "HR", "TEMP"]

# %%
for p in data:
    for m in data[p]:
        if m in measurements:
            for rp in data[p][m]:
                m_df = data[p][m][rp]
                X = m_df['time_seconds'].to_numpy()
                y = m_df[m]
                reg = LinearRegression().fit(X.reshape(-1, 1), y)
                slope = reg.coef_[0]
                intercept = reg.intercept_
                print(p, m, rp)
                print(slope)
# Out:
# -0.029856341860938655
# ('D1_2', 'ID_5') HR ('round_3', 'phase3')
# -0.010764517349233917
# ('D1_2', 'ID_5') HR ('round_2', 'phase3')
# -0.003844363958877594
# ('D1_2', 'ID_5') HR ('round_2', 'phase1')
# -0.012923623242612921
# ('D1_2', 'ID_5') HR ('round_2', 'phase2')
# -0.06773621635243768
# ('D1_2', 'ID_5') HR ('round_1', 'phase2')
# 0.018628439285971302
# ('D1_2', 'ID_5') HR ('round_1', 'phase1')
# -0.013482581433294316
# ('D1_2', 'ID_5') HR ('round_1', 'phase3')
# 0.029127058836391852
# ('D1_2', 'ID_5') TEMP ('round_4', 'phase3')
# 1.707908020117133e-05
# ('D1_2', 'ID_5') TEMP ('round_4', 'phase1')
# 0.00023972992867783683
# ('D1_2', 'ID_5') TEMP ('round_4', 'phase2')
# -4.346197117664702e-05
# ('D1_2', 'ID_5') TEMP ('round_3', 'phase1')
# 0.004714320698249153
# ('D1_2', 'ID_5') TEMP ('round_3', 'phase2')
# 0.0016113679601181003
# ('D1_2', 'ID_5') TEMP ('round_3', 'phase3')
# 0.00013263751889919562
# ('D1_2', 'ID_5') TEMP ('round_2', 'phase3')
# -0.0001083516122649075
# ('D1_2', 'ID_5') TEMP ('round_2', 'phase1')
# 0.0003179868253024376
# ('D1_2', 'ID_5') TEMP ('round_2', 'phase2')
# 0.0004526517608730171
# ('D1_2', 'ID_5') TEMP ('round_1', 'phase2')
# -0.00016850598703088695
# ('D1_2', 'ID_5') TEMP ('round_1', 'phase1')
# 0.0035565484123390406
# ('D1_2', 'ID_5') TEMP ('round_1', 'phase3')
# 0.0024638329170093088
# ('D1_2', 'ID_1') BVP ('round_4', 'phase3')
# 0.00031061483670573206
# ('D1_2', 'ID_1') BVP ('round_4', 'phase1')
# -0.003396331572174407
# ('D1_2', 'ID_1') BVP ('round_4', 'phase2')
# -0.0021940554777057537
# ('D1_2', 'ID_1') BVP ('round_3', 'phase3')
# 0.00031376260945694507
# ('D1_2', 'ID_1') BVP ('round_3', 'phase1')
# 0.000353242733152383
# ('D1_2', 'ID_1') BVP ('round_3', 'phase2')
# -0.0023076776262659533
# ('D1_2', 'ID_1') BVP ('round_1', 'phase2')
# 0.0023708825627026696
# ('D1_2', 'ID_1') BVP ('round_1', 'phase1')
# -0.0018770929905996445
# ('D1_2', 'ID_1') BVP ('round_1', 'phase3')
# 0.0001518634930879579
# ('D1_2', 'ID_1') BVP ('round_2', 'phase1')
# -0.000619855822666051
# ('D1_2', 'ID_1') BVP ('round_2', 'phase2')
# -0.002596813968798305
# ('D1_2', 'ID_1') BVP ('round_2', 'phase3')
# 0.004355474194168354
# ('D1_2', 'ID_1') EDA ('round_4', 'phase3')
# -0.0076194996179612985
# ('D1_2', 'ID_1') EDA ('round_4', 'phase1')
# -0.006430083009898045
# ('D1_2', 'ID_1') EDA ('round_4', 'phase2')
# 0.0019355830400712558
# ('D1_2', 'ID_1') EDA ('round_3', 'phase3')
# -0.0031339724874936232
# ('D1_2', 'ID_1') EDA ('round_3', 'phase1')
# -0.00498903676383548
# ('D1_2', 'ID_1') EDA ('round_3', 'phase2')
# -0.004594730467246978
# ('D1_2', 'ID_1') EDA ('round_1', 'phase2')
# -0.0003881349134964554
# ('D1_2', 'ID_1') EDA ('round_1', 'phase1')
# -0.004207990169640601
# ('D1_2', 'ID_1') EDA ('round_1', 'phase3')
# 2.5987889007162787e-05
# ('D1_2', 'ID_1') EDA ('round_2', 'phase1')
# -0.009333235072558621
# ('D1_2', 'ID_1') EDA ('round_2', 'phase2')
# -0.006499110974050638
# ('D1_2', 'ID_1') EDA ('round_2', 'phase3')
# -0.007890885552048485
# ('D1_2', 'ID_1') HR ('round_4', 'phase3')
# -0.013420409878213331
# ('D1_2', 'ID_1') HR ('round_4', 'phase1')
# -0.004093023255813951
# ('D1_2', 'ID_1') HR ('round_4', 'phase2')
# 0.011270538327496658
# ('D1_2', 'ID_1') HR ('round_3', 'phase3')
# 0.004231811172796038
# ('D1_2', 'ID_1') HR ('round_3', 'phase1')
# -0.01153373894377936
# ('D1_2', 'ID_1') HR ('round_3', 'phase2')
# -0.054092461682078936
# ('D1_2', 'ID_1') HR ('round_1', 'phase2')
# 0.0029881803149438197
# ('D1_2', 'ID_1') HR ('round_1', 'phase1')
# -0.026068937671041417
# ('D1_2', 'ID_1') HR ('round_1', 'phase3')
# 0.015094296424322692
# ('D1_2', 'ID_1') HR ('round_2', 'phase1')
# -0.03642400331997649
# ('D1_2', 'ID_1') HR ('round_2', 'phase2')
# -0.05320198589221071
# ('D1_2', 'ID_1') HR ('round_2', 'phase3')
# 0.0034642159514184675
# ('D1_2', 'ID_1') TEMP ('round_4', 'phase3')
# -0.0005309735646584701
# ('D1_2', 'ID_1') TEMP ('round_4', 'phase1')
# -4.874464548110528e-07
# ('D1_2', 'ID_1') TEMP ('round_4', 'phase2')
# -0.000274769790874087
# ('D1_2', 'ID_1') TEMP ('round_3', 'phase3')
# 0.00033574903910278605
# ('D1_2', 'ID_1') TEMP ('round_3', 'phase1')
# 0.0006158294790650749
# ('D1_2', 'ID_1') TEMP ('round_3', 'phase2')
# -1.28960533147038e-05
# ('D1_2', 'ID_1') TEMP ('round_1', 'phase2')
# 0.0005477016833743633
# ('D1_2', 'ID_1') TEMP ('round_1', 'phase1')
# -0.00024768264198700337
# ('D1_2', 'ID_1') TEMP ('round_1', 'phase3')
# 0.0004398581289708465
# ('D1_2', 'ID_1') TEMP ('round_2', 'phase1')
# 0.0008541224904079288
# ('D1_2', 'ID_1') TEMP ('round_2', 'phase2')
# -0.00027995833139352104
# ('D1_2', 'ID_1') TEMP ('round_2', 'phase3')
# 0.0002777380374555546
# ('D1_2', 'ID_6') BVP ('round_4', 'phase3')
# -0.0033028963230458935
# ('D1_2', 'ID_6') BVP ('round_4', 'phase2')
# 2.7034829094044567e-05
# ('D1_2', 'ID_6') BVP ('round_4', 'phase1')
# -0.004166936239032998
# ('D1_2', 'ID_6') BVP ('round_3', 'phase2')
# 0.0011125580356466636
# ('D1_2', 'ID_6') BVP ('round_3', 'phase1')
# -0.0012582453181067819
# ('D1_2', 'ID_6') BVP ('round_3', 'phase3')
# 0.00359016455765889
# ('D1_2', 'ID_6') BVP ('round_2', 'phase3')
# 0.006391483009609457
# ('D1_2', 'ID_6') BVP ('round_2', 'phase2')
# 0.01282714922321191
# ('D1_2', 'ID_6') BVP ('round_2', 'phase1')
# 0.005883494664712564
# ('D1_2', 'ID_6') BVP ('round_1', 'phase3')
# 0.0032218683683034443
# ('D1_2', 'ID_6') BVP ('round_1', 'phase2')
# 0.002215146676381794
# ('D1_2', 'ID_6') BVP ('round_1', 'phase1')
# -9.43358547893754e-05
# ('D1_2', 'ID_6') EDA ('round_4', 'phase3')
# -0.01697082234764715
# ('D1_2', 'ID_6') EDA ('round_4', 'phase2')
# 0.016705423660077642
# ('D1_2', 'ID_6') EDA ('round_4', 'phase1')
# 0.013896315715354329
# ('D1_2', 'ID_6') EDA ('round_3', 'phase2')
# -0.007821960128797685
# ('D1_2', 'ID_6') EDA ('round_3', 'phase1')
# 0.005461255853917944
# ('D1_2', 'ID_6') EDA ('round_3', 'phase3')
# 0.00916216063537511
# ('D1_2', 'ID_6') EDA ('round_2', 'phase3')
# 0.011744990735268393
# ('D1_2', 'ID_6') EDA ('round_2', 'phase2')
# 0.03971920026842634
# ('D1_2', 'ID_6') EDA ('round_2', 'phase1')
# 0.014412863809007134
# ('D1_2', 'ID_6') EDA ('round_1', 'phase3')
# 0.006890147765622067
# ('D1_2', 'ID_6') EDA ('round_1', 'phase2')
# 0.025574715162340826
# ('D1_2', 'ID_6') EDA ('round_1', 'phase1')
# 0.03221221964698571
# ('D1_2', 'ID_6') HR ('round_4', 'phase3')
# -0.014179491287089948
# ('D1_2', 'ID_6') HR ('round_4', 'phase2')
# 0.02940113959627196
# ('D1_2', 'ID_6') HR ('round_4', 'phase1')
# -0.01613090019041286
# ('D1_2', 'ID_6') HR ('round_3', 'phase2')
# 0.009985710068377838
# ('D1_2', 'ID_6') HR ('round_3', 'phase1')
# 0.01534356677215299
# ('D1_2', 'ID_6') HR ('round_3', 'phase3')
# -0.02603080680293064
# ('D1_2', 'ID_6') HR ('round_2', 'phase3')
# 0.004171820201975756
# ('D1_2', 'ID_6') HR ('round_2', 'phase2')
# -0.016698372374035264
# ('D1_2', 'ID_6') HR ('round_2', 'phase1')
# 0.027818704916020353
# ('D1_2', 'ID_6') HR ('round_1', 'phase3')
# -0.01727285025261674
# ('D1_2', 'ID_6') HR ('round_1', 'phase2')
# 0.02051241680463116
# ('D1_2', 'ID_6') HR ('round_1', 'phase1')
# 0.020119446176714306
# ('D1_2', 'ID_6') TEMP ('round_4', 'phase3')
# -0.0003075239580705591
# ('D1_2', 'ID_6') TEMP ('round_4', 'phase2')
# -0.00034703915667313166
# ('D1_2', 'ID_6') TEMP ('round_4', 'phase1')
# 0.0012180929684415635
# ('D1_2', 'ID_6') TEMP ('round_3', 'phase2')
# -0.0004719559761245553
# ('D1_2', 'ID_6') TEMP ('round_3', 'phase1')
# 0.001430222578782534
# ('D1_2', 'ID_6') TEMP ('round_3', 'phase3')
# 0.00188150794256616
# ('D1_2', 'ID_6') TEMP ('round_2', 'phase3')
# 0.0009826450032001922
# ('D1_2', 'ID_6') TEMP ('round_2', 'phase2')
# 0.0006445480804782408
# ('D1_2', 'ID_6') TEMP ('round_2', 'phase1')
# 0.005324667723382619
# ('D1_2', 'ID_6') TEMP ('round_1', 'phase3')
# 0.0020483467901154686
# ('D1_2', 'ID_6') TEMP ('round_1', 'phase2')
# -0.00011226890856871846
# ('D1_2', 'ID_6') TEMP ('round_1', 'phase1')
# 0.001950929392164813
# ('D1_1', 'ID_4') BVP ('round_2', 'phase3')
# 0.0002208531576386217
# ('D1_1', 'ID_4') BVP ('round_2', 'phase2')
# -0.005846549255332404
# ('D1_1', 'ID_4') BVP ('round_2', 'phase1')
# 0.0013295510594239215
# ('D1_1', 'ID_4') BVP ('round_1', 'phase2')
# 0.0017145929741443785
# ('D1_1', 'ID_4') BVP ('round_1', 'phase1')
# 0.0016259129766148584
# ('D1_1', 'ID_4') BVP ('round_1', 'phase3')
# 0.001631468963493302
# ('D1_1', 'ID_4') BVP ('round_3', 'phase1')
# 0.0013877393918087378
# ('D1_1', 'ID_4') BVP ('round_3', 'phase2')
# -0.0014178971577446416
# ('D1_1', 'ID_4') BVP ('round_3', 'phase3')
# -0.00032784212818713404
# ('D1_1', 'ID_4') BVP ('round_4', 'phase3')
# 0.0005617976435248937
# ('D1_1', 'ID_4') BVP ('round_4', 'phase1')
# -0.009867701660914928
# ('D1_1', 'ID_4') BVP ('round_4', 'phase2')
# 0.0006639197720214287
# ('D1_1', 'ID_4') EDA ('round_2', 'phase3')
# 0.0008234819774180397
# ('D1_1', 'ID_4') EDA ('round_2', 'phase2')
# -0.0013810385996527025
# ('D1_1', 'ID_4') EDA ('round_2', 'phase1')
# 0.00022577218952000514
# ('D1_1', 'ID_4') EDA ('round_1', 'phase2')
# 0.000106527286603572
# ('D1_1', 'ID_4') EDA ('round_1', 'phase1')
# 0.00012898695862500039
# ('D1_1', 'ID_4') EDA ('round_1', 'phase3')
# -0.00013075711888369928
# ('D1_1', 'ID_4') EDA ('round_3', 'phase1')
# -0.0003100974386321082
# ('D1_1', 'ID_4') EDA ('round_3', 'phase2')
# -0.00018916060272863928
# ('D1_1', 'ID_4') EDA ('round_3', 'phase3')
# 3.4671370629289785e-05
# ('D1_1', 'ID_4') EDA ('round_4', 'phase3')
# -0.00020915747634169885
# ('D1_1', 'ID_4') EDA ('round_4', 'phase1')
# -5.0868277975468396e-05
# ('D1_1', 'ID_4') EDA ('round_4', 'phase2')
# -0.00019671028571510444
# ('D1_1', 'ID_4') HR ('round_2', 'phase3')
# 0.028816642407137855
# ('D1_1', 'ID_4') HR ('round_2', 'phase2')
# 0.0016196473903377496
# ('D1_1', 'ID_4') HR ('round_2', 'phase1')
# -0.017800110764956557
# ('D1_1', 'ID_4') HR ('round_1', 'phase2')
# 0.0024925945225944927
# ('D1_1', 'ID_4') HR ('round_1', 'phase1')
# 0.015694165521317194
# ('D1_1', 'ID_4') HR ('round_1', 'phase3')
# -0.06399704906160658
# ('D1_1', 'ID_4') HR ('round_3', 'phase1')
# -0.004753048725217333
# ('D1_1', 'ID_4') HR ('round_3', 'phase2')
# -0.042398196027304956
# ('D1_1', 'ID_4') HR ('round_3', 'phase3')
# -0.045044011698522034
# ('D1_1', 'ID_4') HR ('round_4', 'phase3')
# -0.0010880576561944928
# ('D1_1', 'ID_4') HR ('round_4', 'phase1')
# -0.052068297727222726
# ('D1_1', 'ID_4') HR ('round_4', 'phase2')
# -0.029925234360130625
# ('D1_1', 'ID_4') TEMP ('round_2', 'phase3')
# -0.0017964220808486667
# ('D1_1', 'ID_4') TEMP ('round_2', 'phase2')
# 0.0010508865550330605
# ('D1_1', 'ID_4') TEMP ('round_2', 'phase1')
# 5.6437996085031476e-05
# ('D1_1', 'ID_4') TEMP ('round_1', 'phase2')
# 0.00035785961002057483
# ('D1_1', 'ID_4') TEMP ('round_1', 'phase1')
# -7.756587704474357e-05
# ('D1_1', 'ID_4') TEMP ('round_1', 'phase3')
# -0.0021303357714832307
# ('D1_1', 'ID_4') TEMP ('round_3', 'phase1')
# 0.0003840520947975037
# ('D1_1', 'ID_4') TEMP ('round_3', 'phase2')
# 1.3044441555444996e-05
# ('D1_1', 'ID_4') TEMP ('round_3', 'phase3')
# -0.001438673608679061
# ('D1_1', 'ID_4') TEMP ('round_4', 'phase3')
# -0.0001470850971247727
# ('D1_1', 'ID_4') TEMP ('round_4', 'phase1')
# 0.0012637564220711862
# ('D1_1', 'ID_4') TEMP ('round_4', 'phase2')
# 0.0009624578892911302
# ('D1_1', 'ID_3') BVP ('round_3', 'phase3')
# 0.002442934999678288
# ('D1_1', 'ID_3') BVP ('round_3', 'phase2')
# -8.281831876949983e-05
# ('D1_1', 'ID_3') BVP ('round_3', 'phase1')
# 0.0070571694789382565
# ('D1_1', 'ID_3') BVP ('round_4', 'phase3')
# 0.0012745534671761308
# ('D1_1', 'ID_3') BVP ('round_4', 'phase2')
# 0.000355354469570993
# ('D1_1', 'ID_3') BVP ('round_4', 'phase1')
# 0.004297694281983352
# ('D1_1', 'ID_3') BVP ('round_1', 'phase3')
# -0.004122323704206058
# ('D1_1', 'ID_3') BVP ('round_1', 'phase2')
# -0.0003942101334403637
# ('D1_1', 'ID_3') BVP ('round_1', 'phase1')
# -0.0008411194928732589
# ('D1_1', 'ID_3') BVP ('round_2', 'phase3')
# -0.00039157522219375343
# ('D1_1', 'ID_3') BVP ('round_2', 'phase2')
# 0.0023371952754933194
# ('D1_1', 'ID_3') BVP ('round_2', 'phase1')
# 0.0024978662151375524
# ('D1_1', 'ID_3') EDA ('round_3', 'phase3')
# -0.0027843073920445294
# ('D1_1', 'ID_3') EDA ('round_3', 'phase2')
# 0.0051086864948972095
# ('D1_1', 'ID_3') EDA ('round_3', 'phase1')
# -0.0008734291716292837
# ('D1_1', 'ID_3') EDA ('round_4', 'phase3')
# -0.0006646883768061595
# ('D1_1', 'ID_3') EDA ('round_4', 'phase2')
# -0.0017386349122283905
# ('D1_1', 'ID_3') EDA ('round_4', 'phase1')
# -0.0015098700334954696
# ('D1_1', 'ID_3') EDA ('round_1', 'phase3')
# -0.00261424388301856
# ('D1_1', 'ID_3') EDA ('round_1', 'phase2')
# 0.0028447300187133804
# ('D1_1', 'ID_3') EDA ('round_1', 'phase1')
# -0.0005533801465022682
# ('D1_1', 'ID_3') EDA ('round_2', 'phase3')
# -0.0016635386635856834
# ('D1_1', 'ID_3') EDA ('round_2', 'phase2')
# 0.0019144001861537397
# ('D1_1', 'ID_3') EDA ('round_2', 'phase1')
# -0.0008641442792279793
# ('D1_1', 'ID_3') HR ('round_3', 'phase3')
# -0.05841910547526537
# ('D1_1', 'ID_3') HR ('round_3', 'phase2')
# -0.05239126266175981
# ('D1_1', 'ID_3') HR ('round_3', 'phase1')
# 0.001451998832798372
# ('D1_1', 'ID_3') HR ('round_4', 'phase3')
# -0.062074048479860824
# ('D1_1', 'ID_3') HR ('round_4', 'phase2')
# -0.026056670232367057
# ('D1_1', 'ID_3') HR ('round_4', 'phase1')
# -0.06250356967636063
# ('D1_1', 'ID_3') HR ('round_1', 'phase3')
# -0.07646318057187625
# ('D1_1', 'ID_3') HR ('round_1', 'phase2')
# 0.04315250413508126
# ('D1_1', 'ID_3') HR ('round_1', 'phase1')
# -0.06500762485928564
# ('D1_1', 'ID_3') HR ('round_2', 'phase3')
# -0.045143112723950676
# ('D1_1', 'ID_3') HR ('round_2', 'phase2')
# 0.012921320676002228
# ('D1_1', 'ID_3') HR ('round_2', 'phase1')
# -0.0965104890964151
# ('D1_1', 'ID_3') TEMP ('round_3', 'phase3')
# 0.0068981128081066
# ('D1_1', 'ID_3') TEMP ('round_3', 'phase2')
# -0.003116036042263062
# ('D1_1', 'ID_3') TEMP ('round_3', 'phase1')
# 0.0015034193679175206
# ('D1_1', 'ID_3') TEMP ('round_4', 'phase3')
# 0.00018294153311365272
# ('D1_1', 'ID_3') TEMP ('round_4', 'phase2')
# -0.0030527129331688074
# ('D1_1', 'ID_3') TEMP ('round_4', 'phase1')
# 0.004221585376283625
# ('D1_1', 'ID_3') TEMP ('round_1', 'phase3')
# 0.0038636879537036063
# ('D1_1', 'ID_3') TEMP ('round_1', 'phase2')
# -0.001520155721600443
# ('D1_1', 'ID_3') TEMP ('round_1', 'phase1')
# 0.0003401402523741561
# ('D1_1', 'ID_3') TEMP ('round_2', 'phase3')
# 0.004714390902543104
# ('D1_1', 'ID_3') TEMP ('round_2', 'phase2')
# -0.0019436564406489964
# ('D1_1', 'ID_3') TEMP ('round_2', 'phase1')
# 0.00021428992101094844
# ('D1_1', 'ID_7') BVP ('round_3', 'phase1')
# 0.002505545615618428
# ('D1_1', 'ID_7') BVP ('round_3', 'phase2')
# 0.0030658363585757725
# ('D1_1', 'ID_7') BVP ('round_3', 'phase3')
# -0.0008557385212989682
# ('D1_1', 'ID_7') BVP ('round_4', 'phase1')
# -0.0006608436602927901
# ('D1_1', 'ID_7') BVP ('round_4', 'phase2')
# 0.002859252653804287
# ('D1_1', 'ID_7') BVP ('round_4', 'phase3')
# 0.0013457482679411937
# ('D1_1', 'ID_7') BVP ('round_2', 'phase3')
# -0.0008200330273049157
# ('D1_1', 'ID_7') BVP ('round_2', 'phase2')
# -0.0005708687669428128
# ('D1_1', 'ID_7') BVP ('round_2', 'phase1')
# 0.0009963315980659588
# ('D1_1', 'ID_7') BVP ('round_1', 'phase3')
# -0.0010184278992475405
# ('D1_1', 'ID_7') BVP ('round_1', 'phase1')
# 0.0010563048725781405
# ('D1_1', 'ID_7') BVP ('round_1', 'phase2')
# 0.0004058162529876465
# ('D1_1', 'ID_7') EDA ('round_3', 'phase1')
# -0.0005908749427675006
# ('D1_1', 'ID_7') EDA ('round_3', 'phase2')
# -0.00026117973975661615
# ('D1_1', 'ID_7') EDA ('round_3', 'phase3')
# 8.208249437004229e-05
# ('D1_1', 'ID_7') EDA ('round_4', 'phase1')
# 3.3675001202023485e-05
# ('D1_1', 'ID_7') EDA ('round_4', 'phase2')
# 0.0005972657351715681
# ('D1_1', 'ID_7') EDA ('round_4', 'phase3')
# -0.00012916841453759474
# ('D1_1', 'ID_7') EDA ('round_2', 'phase3')
# -0.0006638388319699148
# ('D1_1', 'ID_7') EDA ('round_2', 'phase2')
# -0.00012984994779027592
# ('D1_1', 'ID_7') EDA ('round_2', 'phase1')
# -0.0009282065240683357
# ('D1_1', 'ID_7') EDA ('round_1', 'phase3')
# -0.00996225632735339
# ('D1_1', 'ID_7') EDA ('round_1', 'phase1')
# -0.006807320455594743
# ('D1_1', 'ID_7') EDA ('round_1', 'phase2')
# 0.00593505900727673
# ('D1_1', 'ID_7') HR ('round_3', 'phase1')
# -0.03036981520861669
# ('D1_1', 'ID_7') HR ('round_3', 'phase2')
# -0.012606623355696834
# ('D1_1', 'ID_7') HR ('round_3', 'phase3')
# -0.013771193896022606
# ('D1_1', 'ID_7') HR ('round_4', 'phase1')
# 0.002158567917892646
# ('D1_1', 'ID_7') HR ('round_4', 'phase2')
# 0.01871255212535531
# ('D1_1', 'ID_7') HR ('round_4', 'phase3')
# -0.03327826481495767
# ('D1_1', 'ID_7') HR ('round_2', 'phase3')
# -0.002149710624977254
# ('D1_1', 'ID_7') HR ('round_2', 'phase2')
# 0.04548732531567691
# ('D1_1', 'ID_7') HR ('round_2', 'phase1')
# 0.005087801297696417
# ('D1_1', 'ID_7') HR ('round_1', 'phase3')
# -0.04035525950288337
# ('D1_1', 'ID_7') HR ('round_1', 'phase1')
# -0.005879664669621938
# ('D1_1', 'ID_7') HR ('round_1', 'phase2')
# -0.02730956484709639
# ('D1_1', 'ID_7') TEMP ('round_3', 'phase1')
# -0.00034693344666871
# ('D1_1', 'ID_7') TEMP ('round_3', 'phase2')
# -0.001495721738111409
# ('D1_1', 'ID_7') TEMP ('round_3', 'phase3')
# 0.0038978502431589322
# ('D1_1', 'ID_7') TEMP ('round_4', 'phase1')
# -0.0012119219623575033
# ('D1_1', 'ID_7') TEMP ('round_4', 'phase2')
# -0.00021625739305898187
# ('D1_1', 'ID_7') TEMP ('round_4', 'phase3')
# -0.00010774934621056636
# ('D1_1', 'ID_7') TEMP ('round_2', 'phase3')
# 0.0023835791828060483
# ('D1_1', 'ID_7') TEMP ('round_2', 'phase2')
# -0.0016619429955765258
# ('D1_1', 'ID_7') TEMP ('round_2', 'phase1')
# 0.0037647477633735446
# ('D1_1', 'ID_7') TEMP ('round_1', 'phase3')
# 0.0035064778242202515
# ('D1_1', 'ID_7') TEMP ('round_1', 'phase1')
# 0.001271555005761221
# ('D1_1', 'ID_7') TEMP ('round_1', 'phase2')
# 0.0009310611040700704
# ('D1_1', 'ID_8') BVP ('round_1', 'phase2')
# 0.0010112558769970984
# ('D1_1', 'ID_8') BVP ('round_1', 'phase1')
# -0.0004267907480666963
# ('D1_1', 'ID_8') BVP ('round_1', 'phase3')
# -0.00022009568907798238
# ('D1_1', 'ID_8') BVP ('round_2', 'phase1')
# 0.006097565108551997
# ('D1_1', 'ID_8') BVP ('round_2', 'phase2')
# -0.0017791908888478715
# ('D1_1', 'ID_8') BVP ('round_2', 'phase3')
# -0.0020386127638251086
# ('D1_1', 'ID_8') BVP ('round_3', 'phase3')
# 0.00018074923145045617
# ('D1_1', 'ID_8') BVP ('round_3', 'phase2')
# -0.0022107383756947607
# ('D1_1', 'ID_8') BVP ('round_3', 'phase1')
# -0.00840581804861924
# ('D1_1', 'ID_8') BVP ('round_4', 'phase1')
# 6.39396855032659e-05
# ('D1_1', 'ID_8') BVP ('round_4', 'phase2')
# -0.0010165187264667584
# ('D1_1', 'ID_8') BVP ('round_4', 'phase3')
# 0.0025332998329203054
# ('D1_1', 'ID_8') EDA ('round_1', 'phase2')
# 0.00035119501883403123
# ('D1_1', 'ID_8') EDA ('round_1', 'phase1')
# 0.0002639058656723636
# ('D1_1', 'ID_8') EDA ('round_1', 'phase3')
# 3.334599755013009e-05
# ('D1_1', 'ID_8') EDA ('round_2', 'phase1')
# -0.00041549899418148305
# ('D1_1', 'ID_8') EDA ('round_2', 'phase2')
# 0.0004686494402633725
# ('D1_1', 'ID_8') EDA ('round_2', 'phase3')
# -0.0004547376370351518
# ('D1_1', 'ID_8') EDA ('round_3', 'phase3')
# -0.00036378478681143634
# ('D1_1', 'ID_8') EDA ('round_3', 'phase2')
# 0.00044959914575023536
# ('D1_1', 'ID_8') EDA ('round_3', 'phase1')
# 0.00012937489685392213
# ('D1_1', 'ID_8') EDA ('round_4', 'phase1')
# -0.00036354946503555484
# ('D1_1', 'ID_8') EDA ('round_4', 'phase2')
# 0.0005368891605099461
# ('D1_1', 'ID_8') EDA ('round_4', 'phase3')
# 0.00011307160678361474
# ('D1_1', 'ID_8') HR ('round_1', 'phase2')
# 0.010650935804048602
# ('D1_1', 'ID_8') HR ('round_1', 'phase1')
# -0.07462037744747566
# ('D1_1', 'ID_8') HR ('round_1', 'phase3')
# -0.026806216146404837
# ('D1_1', 'ID_8') HR ('round_2', 'phase1')
# -0.1575501116663893
# ('D1_1', 'ID_8') HR ('round_2', 'phase2')
# -0.006249574556706652
# ('D1_1', 'ID_8') HR ('round_2', 'phase3')
# -0.004875707181550225
# ('D1_1', 'ID_8') HR ('round_3', 'phase3')
# -0.018970047155707808
# ('D1_1', 'ID_8') HR ('round_3', 'phase2')
# 0.014331326796357461
# ('D1_1', 'ID_8') HR ('round_3', 'phase1')
# -0.04191679171544944
# ('D1_1', 'ID_8') HR ('round_4', 'phase1')
# -0.11024602787047615
# ('D1_1', 'ID_8') HR ('round_4', 'phase2')
# -0.003948225505528036
# ('D1_1', 'ID_8') HR ('round_4', 'phase3')
# -0.04914210516341063
# ('D1_1', 'ID_8') TEMP ('round_1', 'phase2')
# 3.643493761141021e-05
# ('D1_1', 'ID_8') TEMP ('round_1', 'phase1')
# 0.00023229529501712554
# ('D1_1', 'ID_8') TEMP ('round_1', 'phase3')
# -0.001349594704756183
# ('D1_1', 'ID_8') TEMP ('round_2', 'phase1')
# -0.0021187692084192623
# ('D1_1', 'ID_8') TEMP ('round_2', 'phase2')
# -0.00011880818464647634
# ('D1_1', 'ID_8') TEMP ('round_2', 'phase3')
# -0.002760225136741083
# ('D1_1', 'ID_8') TEMP ('round_3', 'phase3')
# 0.001375298793692393
# ('D1_1', 'ID_8') TEMP ('round_3', 'phase2')
# -0.000285631127693065
# ('D1_1', 'ID_8') TEMP ('round_3', 'phase1')
# 0.00023847104810414556
# ('D1_1', 'ID_8') TEMP ('round_4', 'phase1')
# 0.002454198471682501
# ('D1_1', 'ID_8') TEMP ('round_4', 'phase2')
# 0.0013298042741885833
# ('D1_1', 'ID_8') TEMP ('round_4', 'phase3')
# 0.0011648985300303002
# ('D1_1', 'ID_2') BVP ('round_4', 'phase2')
# 0.00041139344520812815
# ('D1_1', 'ID_2') BVP ('round_4', 'phase1')
# 0.00012298557532612085
# ('D1_1', 'ID_2') BVP ('round_4', 'phase3')
# -0.0005907150362337114
# ('D1_1', 'ID_2') BVP ('round_3', 'phase1')
# 0.003942055417764279
# ('D1_1', 'ID_2') BVP ('round_3', 'phase2')
# 0.0010064328014182105
# ('D1_1', 'ID_2') BVP ('round_3', 'phase3')
# -0.00019676026319752677
# ('D1_1', 'ID_2') BVP ('round_1', 'phase2')
# 0.0009171012758424627
# ('D1_1', 'ID_2') BVP ('round_1', 'phase1')
# 0.004301509494088179
# ('D1_1', 'ID_2') BVP ('round_1', 'phase3')
# 6.249676590086723e-05
# ('D1_1', 'ID_2') BVP ('round_2', 'phase3')
# 0.001734624813652521
# ('D1_1', 'ID_2') BVP ('round_2', 'phase2')
# -0.0033510665548374175
# ('D1_1', 'ID_2') BVP ('round_2', 'phase1')
# 0.000332870668858171
# ('D1_1', 'ID_2') EDA ('round_4', 'phase2')
# 0.0003353169734893922
# ('D1_1', 'ID_2') EDA ('round_4', 'phase1')
# -0.00018024362334080504
# ('D1_1', 'ID_2') EDA ('round_4', 'phase3')
# -0.0001648214606594886
# ('D1_1', 'ID_2') EDA ('round_3', 'phase1')
# -0.00033340604999966604
# ('D1_1', 'ID_2') EDA ('round_3', 'phase2')
# -0.0006382479114864072
# ('D1_1', 'ID_2') EDA ('round_3', 'phase3')
# 0.00011626604125425191
# ('D1_1', 'ID_2') EDA ('round_1', 'phase2')
# 0.0007709981104021509
# ('D1_1', 'ID_2') EDA ('round_1', 'phase1')
# -0.0009272741992467534
# ('D1_1', 'ID_2') EDA ('round_1', 'phase3')
# 0.00033420654431287557
# ('D1_1', 'ID_2') EDA ('round_2', 'phase3')
# -0.00032270072323782633
# ('D1_1', 'ID_2') EDA ('round_2', 'phase2')
# 0.0005711720945735149
# ('D1_1', 'ID_2') EDA ('round_2', 'phase1')
# 9.417885721127807e-05
# ('D1_1', 'ID_2') HR ('round_4', 'phase2')
# -0.07641906559697971
# ('D1_1', 'ID_2') HR ('round_4', 'phase1')
# -0.011865596895872653
# ('D1_1', 'ID_2') HR ('round_4', 'phase3')
# -0.024445482406130613
# ('D1_1', 'ID_2') HR ('round_3', 'phase1')
# 0.01386250328473848
# ('D1_1', 'ID_2') HR ('round_3', 'phase2')
# 0.03716660516065713
# ('D1_1', 'ID_2') HR ('round_3', 'phase3')
# 0.020645722309631364
# ('D1_1', 'ID_2') HR ('round_1', 'phase2')
# -0.017083727359334177
# ('D1_1', 'ID_2') HR ('round_1', 'phase1')
# 0.06886191080511227
# ('D1_1', 'ID_2') HR ('round_1', 'phase3')
# -0.06779825981867339
# ('D1_1', 'ID_2') HR ('round_2', 'phase3')
# -0.044016548472576175
# ('D1_1', 'ID_2') HR ('round_2', 'phase2')
# 0.07921241439763531
# ('D1_1', 'ID_2') HR ('round_2', 'phase1')
# -0.011523391696377987
# ('D1_1', 'ID_2') TEMP ('round_4', 'phase2')
# 0.0003782918474391395
# ('D1_1', 'ID_2') TEMP ('round_4', 'phase1')
# -0.001286502656153891
# ('D1_1', 'ID_2') TEMP ('round_4', 'phase3')
# -0.0009500123189095752
# ('D1_1', 'ID_2') TEMP ('round_3', 'phase1')
# -0.0008124585624488667
# ('D1_1', 'ID_2') TEMP ('round_3', 'phase2')
# 6.40092160059032e-05
# ('D1_1', 'ID_2') TEMP ('round_3', 'phase3')
# -0.0004274360242270937
# ('D1_1', 'ID_2') TEMP ('round_1', 'phase2')
# -0.0009391274652095996
# ('D1_1', 'ID_2') TEMP ('round_1', 'phase1')
# -0.00395110085116575
# ('D1_1', 'ID_2') TEMP ('round_1', 'phase3')
# -0.0011362351518469484
# ('D1_1', 'ID_2') TEMP ('round_2', 'phase3')
# 0.000115956225569097
# ('D1_1', 'ID_2') TEMP ('round_2', 'phase2')
# -0.0010205501727698478
# ('D1_1', 'ID_2') TEMP ('round_2', 'phase1')
# 0.001121111179907573
# ('D1_1', 'ID_5') BVP ('round_1', 'phase1')
# 0.00025423439824771415
# ('D1_1', 'ID_5') BVP ('round_1', 'phase2')
# 0.0005228715317816127
# ('D1_1', 'ID_5') BVP ('round_1', 'phase3')
# 5.891112188022803e-05
# ('D1_1', 'ID_5') BVP ('round_2', 'phase1')
# 0.0010004291011733292
# ('D1_1', 'ID_5') BVP ('round_2', 'phase2')
# 0.0006343432275029742
# ('D1_1', 'ID_5') BVP ('round_2', 'phase3')
# 0.0013950630735564907
# ('D1_1', 'ID_5') BVP ('round_4', 'phase3')
# -0.0001102106981964017
# ('D1_1', 'ID_5') BVP ('round_4', 'phase2')
# -0.00012796137394442453
# ('D1_1', 'ID_5') BVP ('round_4', 'phase1')
# 0.00204115795958416
# ('D1_1', 'ID_5') BVP ('round_3', 'phase2')
# 0.0001774324517501301
# ('D1_1', 'ID_5') BVP ('round_3', 'phase1')
# 0.005111161923825338
# ('D1_1', 'ID_5') BVP ('round_3', 'phase3')
# 0.003106722092459688
# ('D1_1', 'ID_5') EDA ('round_1', 'phase1')
# -0.00041445165476182455
# ('D1_1', 'ID_5') EDA ('round_1', 'phase2')
# 0.0023938731415072624
# ('D1_1', 'ID_5') EDA ('round_1', 'phase3')
# -0.0021815227760959093
# ('D1_1', 'ID_5') EDA ('round_2', 'phase1')
# -0.000480338975766543
# ('D1_1', 'ID_5') EDA ('round_2', 'phase2')
# 0.0005326775786565306
# ('D1_1', 'ID_5') EDA ('round_2', 'phase3')
# -0.0024106988142798386
# ('D1_1', 'ID_5') EDA ('round_4', 'phase3')
# -0.001957963428999914
# ('D1_1', 'ID_5') EDA ('round_4', 'phase2')
# -0.0008835755170387562
# ('D1_1', 'ID_5') EDA ('round_4', 'phase1')
# -0.00011732289190579827
# ('D1_1', 'ID_5') EDA ('round_3', 'phase2')
# -6.474320009960946e-05
# ('D1_1', 'ID_5') EDA ('round_3', 'phase1')
# -0.002215722437626019
# ('D1_1', 'ID_5') EDA ('round_3', 'phase3')
# -0.0010676552737112499
# ('D1_1', 'ID_5') HR ('round_1', 'phase1')
# -0.029587514080631507
# ('D1_1', 'ID_5') HR ('round_1', 'phase2')
# -0.05894638515563277
# ('D1_1', 'ID_5') HR ('round_1', 'phase3')
# -0.02907828355973192
# ('D1_1', 'ID_5') HR ('round_2', 'phase1')
# -0.04279547953780304
# ('D1_1', 'ID_5') HR ('round_2', 'phase2')
# 0.004165950755177285
# ('D1_1', 'ID_5') HR ('round_2', 'phase3')
# -0.03476919335464989
# ('D1_1', 'ID_5') HR ('round_4', 'phase3')
# -0.01928134297841139
# ('D1_1', 'ID_5') HR ('round_4', 'phase2')
# -0.0466225295811957
# ('D1_1', 'ID_5') HR ('round_4', 'phase1')
# -0.12900689729125023
# ('D1_1', 'ID_5') HR ('round_3', 'phase2')
# -0.02766796611783318
# ('D1_1', 'ID_5') HR ('round_3', 'phase1')
# -0.02002458424110015
# ('D1_1', 'ID_5') HR ('round_3', 'phase3')
# -0.01349566062729504
# ('D1_1', 'ID_5') TEMP ('round_1', 'phase1')
# -0.00045482213762673403
# ('D1_1', 'ID_5') TEMP ('round_1', 'phase2')
# 0.0014885889121515471
# ('D1_1', 'ID_5') TEMP ('round_1', 'phase3')
# 0.002706380422415575
# ('D1_1', 'ID_5') TEMP ('round_2', 'phase1')
# -0.0018816410458866212
# ('D1_1', 'ID_5') TEMP ('round_2', 'phase2')
# -0.0005983309578779638
# ('D1_1', 'ID_5') TEMP ('round_2', 'phase3')
# -0.002835914727890793
# ('D1_1', 'ID_5') TEMP ('round_4', 'phase3')
# 0.0006796839724893486
# ('D1_1', 'ID_5') TEMP ('round_4', 'phase2')
# 0.0014073896796285236
# ('D1_1', 'ID_5') TEMP ('round_4', 'phase1')
# -0.0013245209351184098
# ('D1_1', 'ID_5') TEMP ('round_3', 'phase2')
# 5.005007937627244e-05
# ('D1_1', 'ID_5') TEMP ('round_3', 'phase1')
# -0.0001456923426540057
# ('D1_1', 'ID_5') TEMP ('round_3', 'phase3')
# -0.0007680347232961619
# ('D1_1', 'ID_1') BVP ('round_4', 'phase3')
# 0.0037490685459716094
# ('D1_1', 'ID_1') BVP ('round_4', 'phase2')
# -0.0010180394725800856
# ('D1_1', 'ID_1') BVP ('round_4', 'phase1')
# 0.004266941036590078
# ('D1_1', 'ID_1') BVP ('round_3', 'phase1')
# 0.0021300180758101143
# ('D1_1', 'ID_1') BVP ('round_3', 'phase2')
# 0.005318470965880908
# ('D1_1', 'ID_1') BVP ('round_3', 'phase3')
# -0.0015213197410692762
# ('D1_1', 'ID_1') BVP ('round_1', 'phase3')
# -0.0007563797087952954
# ('D1_1', 'ID_1') BVP ('round_1', 'phase2')
# 0.0026840529329234066
# ('D1_1', 'ID_1') BVP ('round_1', 'phase1')
# 0.0012642438474529682
# ('D1_1', 'ID_1') BVP ('round_2', 'phase3')
# 0.00014384746211383145
# ('D1_1', 'ID_1') BVP ('round_2', 'phase2')
# -0.00229638302953178
# ('D1_1', 'ID_1') BVP ('round_2', 'phase1')
# -0.0006591219644792665
# ('D1_1', 'ID_1') EDA ('round_4', 'phase3')
# 5.752885143753511e-05
# ('D1_1', 'ID_1') EDA ('round_4', 'phase2')
# 1.4530609996489162e-05
# ('D1_1', 'ID_1') EDA ('round_4', 'phase1')
# -0.000171557840188596
# ('D1_1', 'ID_1') EDA ('round_3', 'phase1')
# -0.0001017485425390761
# ('D1_1', 'ID_1') EDA ('round_3', 'phase2')
# -0.00026797696202143973
# ('D1_1', 'ID_1') EDA ('round_3', 'phase3')
# -0.0002522269268998138
# ('D1_1', 'ID_1') EDA ('round_1', 'phase3')
# -7.322892929429623e-05
# ('D1_1', 'ID_1') EDA ('round_1', 'phase2')
# 6.614921385156546e-05
# ('D1_1', 'ID_1') EDA ('round_1', 'phase1')
# 0.00027475984947862396
# ('D1_1', 'ID_1') EDA ('round_2', 'phase3')
# -6.464582914180392e-05
# ('D1_1', 'ID_1') EDA ('round_2', 'phase2')
# -0.00013421203653899731
# ('D1_1', 'ID_1') EDA ('round_2', 'phase1')
# -0.00010037616233239955
# ('D1_1', 'ID_1') HR ('round_4', 'phase3')
# 0.006584848238922255
# ('D1_1', 'ID_1') HR ('round_4', 'phase2')
# -0.009931193958705689
# ('D1_1', 'ID_1') HR ('round_4', 'phase1')
# -0.017939169852492307
# ('D1_1', 'ID_1') HR ('round_3', 'phase1')
# -0.06331615172219203
# ('D1_1', 'ID_1') HR ('round_3', 'phase2')
# 0.007051197290977981
# ('D1_1', 'ID_1') HR ('round_3', 'phase3')
# -0.019206754526853095
# ('D1_1', 'ID_1') HR ('round_1', 'phase3')
# -0.00608206010230861
# ('D1_1', 'ID_1') HR ('round_1', 'phase2')
# 0.0029794091549663294
# ('D1_1', 'ID_1') HR ('round_1', 'phase1')
# 0.00333946067963964
# ('D1_1', 'ID_1') HR ('round_2', 'phase3')
# -0.014173477139537559
# ('D1_1', 'ID_1') HR ('round_2', 'phase2')
# -0.005166234134070613
# ('D1_1', 'ID_1') HR ('round_2', 'phase1')
# -0.003443357970090365
# ('D1_1', 'ID_1') TEMP ('round_4', 'phase3')
# -0.00047085180006226204
# ('D1_1', 'ID_1') TEMP ('round_4', 'phase2')
# 0.00023838397519741994
# ('D1_1', 'ID_1') TEMP ('round_4', 'phase1')
# 0.0006910383310442946
# ('D1_1', 'ID_1') TEMP ('round_3', 'phase1')
# 0.00045937991421124164
# ('D1_1', 'ID_1') TEMP ('round_3', 'phase2')
# 0.0005285644954876932
# ('D1_1', 'ID_1') TEMP ('round_3', 'phase3')
# 0.0007220618997439556
# ('D1_1', 'ID_1') TEMP ('round_1', 'phase3')
# 0.0008329462077642183
# ('D1_1', 'ID_1') TEMP ('round_1', 'phase2')
# 0.0015649846262764796
# ('D1_1', 'ID_1') TEMP ('round_1', 'phase1')
# 0.0002252981011882378
# ('D1_1', 'ID_1') TEMP ('round_2', 'phase3')
# 0.0012209567816196208
# ('D1_1', 'ID_1') TEMP ('round_2', 'phase2')
# 0.0011678930724926477
# ('D1_1', 'ID_1') TEMP ('round_2', 'phase1')
# 0.001017557562400506
# ('D1_1', 'ID_6') BVP ('round_4', 'phase3')
# -7.743381908806948e-07
# ('D1_1', 'ID_6') BVP ('round_4', 'phase1')
# 0.0008304034276900115
# ('D1_1', 'ID_6') BVP ('round_4', 'phase2')
# -0.0008045843376909308
# ('D1_1', 'ID_6') BVP ('round_3', 'phase3')
# 0.0033705241235207125
# ('D1_1', 'ID_6') BVP ('round_3', 'phase1')
# -0.0027264740855492513
# ('D1_1', 'ID_6') BVP ('round_3', 'phase2')
# -0.0076160048755666366
# ('D1_1', 'ID_6') BVP ('round_1', 'phase1')
# -0.0005077355607651286
# ('D1_1', 'ID_6') BVP ('round_1', 'phase2')
# 4.937606329694516e-05
# ('D1_1', 'ID_6') BVP ('round_1', 'phase3')
# 0.0073575966537831605
# ('D1_1', 'ID_6') BVP ('round_2', 'phase3')
# 0.003639684705127691
# ('D1_1', 'ID_6') BVP ('round_2', 'phase2')
# -0.004026549833698571
# ('D1_1', 'ID_6') BVP ('round_2', 'phase1')
# 0.0025092023501095736
# ('D1_1', 'ID_6') EDA ('round_4', 'phase3')
# -0.0012060470053525312
# ('D1_1', 'ID_6') EDA ('round_4', 'phase1')
# -0.0012865505164897423
# ('D1_1', 'ID_6') EDA ('round_4', 'phase2')
# 4.326801271170781e-05
# ('D1_1', 'ID_6') EDA ('round_3', 'phase3')
# -0.0008826152143184413
# ('D1_1', 'ID_6') EDA ('round_3', 'phase1')
# -0.0006077974292115091
# ('D1_1', 'ID_6') EDA ('round_3', 'phase2')
# 0.00011864899039975776
# ('D1_1', 'ID_6') EDA ('round_1', 'phase1')
# -1.0253505624998833e-05
# ('D1_1', 'ID_6') EDA ('round_1', 'phase2')
# -0.00014372112422363792
# ('D1_1', 'ID_6') EDA ('round_1', 'phase3')
# -0.0020183626893929578
# ('D1_1', 'ID_6') EDA ('round_2', 'phase3')
# -0.00034367364722802125
# ('D1_1', 'ID_6') EDA ('round_2', 'phase2')
# -0.0015032365591125746
# ('D1_1', 'ID_6') EDA ('round_2', 'phase1')
# -0.001079050947597531
# ('D1_1', 'ID_6') HR ('round_4', 'phase3')
# 0.001937782182398104
# ('D1_1', 'ID_6') HR ('round_4', 'phase1')
# -0.047823710051364196
# ('D1_1', 'ID_6') HR ('round_4', 'phase2')
# -0.04200705818265493
# ('D1_1', 'ID_6') HR ('round_3', 'phase3')
# -0.006506597897342315
# ('D1_1', 'ID_6') HR ('round_3', 'phase1')
# -0.09622093875449582
# ('D1_1', 'ID_6') HR ('round_3', 'phase2')
# 0.010941739342500194
# ('D1_1', 'ID_6') HR ('round_1', 'phase1')
# -0.01731471422592445
# ('D1_1', 'ID_6') HR ('round_1', 'phase2')
# -0.08486970812206798
# ('D1_1', 'ID_6') HR ('round_1', 'phase3')
# -0.14185125361944742
# ('D1_1', 'ID_6') HR ('round_2', 'phase3')
# -0.03619304703476482
# ('D1_1', 'ID_6') HR ('round_2', 'phase2')
# -0.015153934522855496
# ('D1_1', 'ID_6') HR ('round_2', 'phase1')
# -0.022598504623187462
# ('D1_1', 'ID_6') TEMP ('round_4', 'phase3')
# 0.0008828707684898399
# ('D1_1', 'ID_6') TEMP ('round_4', 'phase1')
# -0.00042129150080399925
# ('D1_1', 'ID_6') TEMP ('round_4', 'phase2')
# -0.0006527994087577783
# ('D1_1', 'ID_6') TEMP ('round_3', 'phase3')
# 0.0005420019043344221
# ('D1_1', 'ID_6') TEMP ('round_3', 'phase1')
# -0.0005677902631348463
# ('D1_1', 'ID_6') TEMP ('round_3', 'phase2')
# 0.0004433030007287087
# ('D1_1', 'ID_6') TEMP ('round_1', 'phase1')
# -0.0004070823518326284
# ('D1_1', 'ID_6') TEMP ('round_1', 'phase2')
# -0.00032647024533027165
# ('D1_1', 'ID_6') TEMP ('round_1', 'phase3')
# -0.0006244329525123454
# ('D1_1', 'ID_6') TEMP ('round_2', 'phase3')
# -0.00048539215120026744
# ('D1_1', 'ID_6') TEMP ('round_2', 'phase2')
# 0.0002968830315974904
# ('D1_1', 'ID_6') TEMP ('round_2', 'phase1')
# 0.000247071214009654

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=aad321cd-5b13-4522-860e-4bbfa7104698' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
